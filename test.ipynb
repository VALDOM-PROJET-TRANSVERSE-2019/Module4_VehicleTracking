# %%
import cv2
import json
contours = []

with open("data/bounding_boxes/image11.json") as f:
    data = json.load(f)
    for elem in data:
        x = elem["left"]
        y = elem["top"]
        w = elem["right"] - elem["left"]
        h =  elem["bot"] - elem["top"]
        contours.append((x,y,w,h))

# %%
frame = cv2.imread("data/image/image" + str(11) + ".jpg")

# %%
cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 1)
cv2.putText(frame, "vehicle", (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1, cv2.LINE_AA)


  


cv2.imshow("test",frame)

cv2.waitKey()  
cv2.destroyAllWindows()

# %%
import cv2
import json
import matplotlib.pyplot as plt
frame = cv2.imread("data/image/image" + str(11) + ".jpg")
plt.imshow(frame)
print(frame[0,0])
"left": 40, "bot": 196, "right": 184, "top": 127
# Out:
# [145 138 135]

# %%
bounding_box = (40,127,184-40,196-127)
img = frame[bounding_box[1]:bounding_box[1] + bounding_box[3],
              bounding_box[0]: bounding_box[0] + bounding_box[2]]
plt.imshow(img
)

# %%
import numpy as np
array = np.array(img)
img.mean(axis=1)
# Out:
# array([[ 78.35416667,  73.63888889,  78.5       ],
#        [ 79.65277778,  73.625     ,  80.35416667],
#        [ 79.30555556,  72.79166667,  79.47222222],
#        [ 81.17361111,  75.09027778,  79.70138889],
#        [ 94.25      ,  88.36111111,  91.15277778],
#        [100.8125    ,  95.00694444,  96.36805556],
#        [100.34722222,  94.45833333,  94.97916667],
#        [111.42361111, 105.14583333, 105.22222222],
#        [129.44444444, 123.17361111, 122.95833333],
#        [117.71527778, 111.67361111, 111.17361111],
#        [102.06944444,  96.06944444,  95.58333333],
#        [107.47916667, 101.28472222, 100.91666667],
#        [115.96527778, 109.77777778, 109.52083333],
#        [122.69444444, 116.43055556, 116.30555556],
#        [122.6875    , 116.51388889, 116.17361111],
#        [121.5       , 115.54166667, 114.51388889],
#        [120.84722222, 114.97222222, 113.52083333],
#        [119.46527778, 113.52777778, 111.79166667],
#        [115.95138889, 110.40972222, 108.86805556],
#        [112.0625    , 106.91666667, 106.40277778],
#        [115.50694444, 110.95833333, 111.29861111],
#        [118.01388889, 114.19444444, 115.04166667],
#        [115.72916667, 111.76388889, 113.20833333],
#        [114.46527778, 109.49305556, 111.53472222],
#        [120.27083333, 115.40972222, 117.60416667],
#        [123.13194444, 119.40972222, 121.47916667],
#        [123.19444444, 119.23611111, 120.75      ],
#        [123.75694444, 118.18055556, 118.79861111],
#        [124.21527778, 117.72916667, 118.54166667],
#        [126.64583333, 119.65277778, 121.69444444],
#        [130.04861111, 122.79861111, 125.58333333],
#        [130.01388889, 122.54861111, 125.25694444],
#        [126.70833333, 119.43055556, 120.47916667],
#        [127.85416667, 121.08333333, 118.70138889],
#        [127.57638889, 121.19444444, 116.86111111],
#        [126.77083333, 120.5625    , 116.00694444],
#        [122.97916667, 116.82638889, 112.13194444],
#        [116.15972222, 110.15277778, 105.26388889],
#        [113.70138889, 107.73611111, 102.80555556],
#        [111.57638889, 105.72916667, 100.8125    ],
#        [108.10416667, 102.27777778,  97.60416667],
#        [107.13888889, 101.42361111,  96.84722222],
#        [108.06944444, 102.20138889,  98.03472222],
#        [108.6875    , 102.86805556,  99.02083333],
#        [108.58333333, 102.65277778,  99.03472222],
#        [107.97222222, 102.08333333,  98.59722222],
#        [107.75      , 101.83333333,  98.4375    ],
#        [108.35416667, 102.43055556,  99.21527778],
#        [108.82638889, 102.95833333, 100.27777778],
#        [107.58333333, 101.42361111,  99.9375    ],
#        [105.15277778,  99.03472222,  98.08333333],
#        [114.67361111, 108.54166667, 107.45833333],
#        [117.16666667, 110.75      , 109.90972222],
#        [108.81944444, 101.66666667, 101.69444444],
#        [111.47916667, 104.15277778, 104.26388889],
#        [118.18055556, 110.79861111, 110.02083333],
#        [106.97916667,  99.65277778,  98.69444444],
#        [ 92.88888889,  85.95833333,  84.84722222],
#        [ 90.82638889,  83.96527778,  82.9375    ],
#        [ 81.91666667,  76.13194444,  76.02777778],
#        [ 77.92361111,  72.36111111,  72.13194444],
#        [ 72.125     ,  67.86111111,  67.93055556],
#        [ 62.09722222,  58.0625    ,  57.99305556],
#        [ 59.81944444,  56.76388889,  57.22222222],
#        [ 41.81944444,  39.32638889,  39.49305556],
#        [ 36.42361111,  35.29166667,  35.13194444],
#        [ 41.63888889,  40.63888889,  40.47222222],
#        [ 24.85416667,  24.07638889,  23.90972222],
#        [ 21.96527778,  21.1875    ,  21.02083333]])

# %%
img.shape[0][0][2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-b57c42f7434c> in <module>
# ----> 1 img.shape[0][0][2]
#       2
#
# TypeError: 'int' object is not subscriptable

# %%
print(np.mean(img[:,:,0]),np.mean(img[:,:,1]),np.mean(img[:,:,2]))
# Out:
# 103.46869967793882 97.92572463768116 97.44323671497584

# %%
np.array((3,6))-np.array((1,0))
# Out:
# array([2, 6])
